# %% [markdown]
# <a href="https://colab.research.google.com/github/MbongeniMQ7/API-INTERGRATION/blob/main/Tutorial4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# CREATE a DataFrame that store 5 students with their marks, names, and age


import pandas as pd

students = {
    "Name": ["Mbongeni", "Thuto", "Kamogelo", "Sarah", "Petersam"],
    "Age": [20, 27, 26, 29, 30],
    "Mark": [56, 76, 87, 90,47]
}

df = pd.DataFrame(students)

#print(df)

#print(df.head())
#print(df.shape)

#print(df.columns)

#print("Average Mark: ", df["Mark"].min())

print(df.describe())
# Out:
#              Age       Mark
# count   5.000000   5.000000
# mean   26.400000  71.200000
# std     3.911521  18.992104
# min    20.000000  47.000000
# 25%    26.000000  56.000000
# 50%    27.000000  76.000000
# 75%    29.000000  87.000000
# max    30.000000  90.000000
